# %% [markdown]
# <a href="https://colab.research.google.com/github/Aiswarya444/NGS-SRA-to-FASTQ/blob/main/NGS_SRA_to_FASTQ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://ftp-trace.ncbi.nlm.nih.gov/sra/sdk/current/sratoolkit.current-ubuntu64.tar.gz
# Out:
# --2026-08-12 20:02:46--  https://ftp-trace.ncbi.nlm.nih.gov/sra/sdk/current/sratoolkit.current-ubuntu64.tar.gz
# Resolving ftp-trace.ncbi.nlm.nih.gov (ftp-trace.ncbi.nlm.nih.gov)... 130.14.250.11, 130.14.250.12, 2607:f220:41e:250::10, ...
# Connecting to ftp-trace.ncbi.nlm.nih.gov (ftp-trace.ncbi.nlm.nih.gov)|130.14.250.11|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 89143120 (85M) [application/x-gzip]
# Saving to: ‘sratoolkit.current-ubuntu64.tar.gz’
#
# sratoolkit.current- 100%[===================>]  85.01M   130MB/s    in 0.7s
#
# 2026-08-12 20:02:47 (130 MB/s) - ‘sratoolkit.current-ubuntu64.tar.gz’ saved [89143120/89143120]

# %%
# !tar -xzf sratoolkit.current-ubuntu64.tar.gz
# Out:
# tar (child): sratoolkit.current-ubuntu64.tar.gz: Cannot open: No such file or directory
# tar (child): Error is not recoverable: exiting now
# tar: Child returned status 2
# tar: Error is not recoverable: exiting now

# %%
# !ls
# Out:
# sample_data

# %%
# !wget https://ftp-trace.ncbi.nlm.nih.gov/sra/sdk/current/sratoolkit.current-ubuntu64.tar.gz
# Out:
# --2026-08-13 06:06:45--  https://ftp-trace.ncbi.nlm.nih.gov/sra/sdk/current/sratoolkit.current-ubuntu64.tar.gz
# Resolving ftp-trace.ncbi.nlm.nih.gov (ftp-trace.ncbi.nlm.nih.gov)... 130.14.250.13, 130.14.250.31, 2607:f220:41e:250::10, ...
# Connecting to ftp-trace.ncbi.nlm.nih.gov (ftp-trace.ncbi.nlm.nih.gov)|130.14.250.13|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 89143120 (85M) [application/x-gzip]
# Saving to: ‘sratoolkit.current-ubuntu64.tar.gz’
#
# sratoolkit.current- 100%[===================>]  85.01M   110MB/s    in 0.8s
#
# 2026-08-13 06:06:46 (110 MB/s) - ‘sratoolkit.current-ubuntu64.tar.gz’ saved [89143120/89143120]

# %%
# !ls
# Out:
# sample_data  sratoolkit.current-ubuntu64.tar.gz

# %%
# !tar -xzf sratoolkit.current-ubuntu64.tar.gz

# %%
# !ls
# Out:
# sample_data  sratoolkit.3.4.1-ubuntu64	sratoolkit.current-ubuntu64.tar.gz

# %%
# %cd sratoolkit.3.4.1-ubuntu64
# Out:
# /content/sratoolkit.3.4.1-ubuntu64

# %%
import os
os.environ["PATH"] += ":" + os.getcwd() + "/bin"

# %%
# !which prefetch
# !which fasterq-dump
# Out:
# /content/sratoolkit.3.4.1-ubuntu64/bin/prefetch
# /content/sratoolkit.3.4.1-ubuntu64/bin/fasterq-dump

# %%
# !prefetch --version
# !fasterq-dump --version
# Out:
# prefetch : 3.4.1
#
# fasterq-dump : 3.4.1

# %%
SRR_ID = "SRR1553607"

# %%
# !prefetch $SRR_ID
# Out:
# 2026-08-13T06:26:31 prefetch.3.4.1: 1) Resolving 'SRR1553607'...
# 2026-08-13T06:26:31 prefetch.3.4.1: Current preference is set to retrieve SRA Normalized Format files with full base quality scores
# 2026-08-13T06:26:31 prefetch.3.4.1: 1) Downloading 'SRR1553607'...
# 2026-08-13T06:26:31 prefetch.3.4.1:  SRA Normalized Format file is being retrieved
# 2026-08-13T06:26:31 prefetch.3.4.1:  Downloading via HTTPS...
# 2026-08-13T06:26:32 prefetch.3.4.1:  HTTPS download succeed
# 2026-08-13T06:26:33 prefetch.3.4.1:  'SRR1553607' is valid: 25453427 bytes were streamed from 25451481
# 2026-08-13T06:26:33 prefetch.3.4.1: 1) 'SRR1553607' was downloaded successfully
# 2026-08-13T06:26:33 prefetch.3.4.1: 1) Resolving 'SRR1553607's dependencies...
# 2026-08-13T06:26:33 prefetch.3.4.1: 'SRR1553607' has 0 unresolved dependencies

# %%
# !fasterq-dump $SRR_ID --split-files
# Out:
# spots read      : 203,445
# reads read      : 406,890
# reads written   : 406,890
